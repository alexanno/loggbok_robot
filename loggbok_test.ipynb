# %% [markdown]
# ## Ideer
# * Hente data fra yr.no for siste døgn (eller dager?)
#     * nowcast for Frierholmen: https://api.met.no/weatherapi/nowcast/2.0/complete?lat=58.62151&lon=9.06186
#     * Lagre i en duckdb database
# * Hente data fra en sensor på gitte intervall. Lagre i en duckdb-database
#
# * Hente ut data fra et gitt intervall og lage som csv-tekst
#
# * Kjøre en gpt-request som lager en loggbok. Lagre loggboken i duckdb-databasen.
#
# * Bruke duckdb til å sende data til en server (supabase, drive-mappe, github-lfs-repo)
# * Lage html-fil med siste logg - laste opp til github-repo med pages?

# %% [markdown]
# ## Notater
# * https://digitaltmuseum.no/021019251519/dypvag-sett-fra-seilbat-under-seiling-tur-retur-stavanger-i-juli-1922-kirketarnet

# %% [markdown]
# # GenAI Loggbok
